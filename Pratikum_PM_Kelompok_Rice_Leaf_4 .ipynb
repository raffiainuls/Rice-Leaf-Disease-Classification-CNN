# %%
#import library 
import pandas as pd
import numpy as np
import os, cv2, shutil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, Flatten,BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from google.colab import files
from keras.preprocessing import image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Definisikan path kaggle json
# Sesuaikan dengan path anda
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/Pratikum"

# %%
# Ubah lokasi direktori kerja
# Sesuaikan dengan path anda
# %cd /content/drive/My Drive/Pratikum
# Out:
# /content/drive/My Drive/Pratikum

# %%
# Cek apakah api sudah terbaca oleh sistem
# !ls
# Out:
#  Accuracy.svg   logs			       'Rice Leaf Disease Model 1.json'
#  dataset        model_plot.png		       'Rice Leaf Disease Model 2.h5'
#  Dataset        model.tflite		       'Rice Leaf Disease Model 2.json'
#  kaggle.json   'Rice Leaf Disease Model 1.h5'   rice_leaf_diseases

# %%
# !kaggle datasets download -d vbookshelf/rice-leaf-diseases
# Out:
# Downloading rice-leaf-diseases.zip to /content/drive/My Drive/Pratikum
# 100% 36.7M/36.7M [00:00<00:00, 26.1MB/s]

# %%
# Cek isi direktori kerja dan memastikan dataset telah berhasil didownload.
# !ls
# Out:
# kaggle.json  rice-leaf-diseases.zip

# %%
# Ekstrak file dataset dan hapus file zip dataset agar tidak memakan banyak tempat.
# !unzip \*.zip &> /dev/null && rm *.zip

# %%
# !ls
# Out:
# kaggle.json  rice_leaf_diseases

# %%
# !mkdir dataset

# %%
# !ls
# Out:
# dataset  kaggle.json  rice_leaf_diseases

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.4.3-py3-none-any.whl (7.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.4.3

# %%
import splitfolders


base_dir = '/content/drive/MyDrive/Pratikum/rice_leaf_diseases'
data_dir = '/content/drive/My Drive/Pratikum/Dataset'

splitfolders.ratio(base_dir, output=data_dir, seed=1337, ratio=(.8, .19, .01),group_prefix=None)

# %%
train_dir=os.path.join('/content/drive/My Drive/Pratikum/dataset/train')
test_dir=os.path.join('/content/drive/My Drive/chest_xray/test')
val_dir=os.path.join('/content/drive/My Drive/chest_xray/val')

# %%
# TULIS KODE ANDA DISINI
datagen = ImageDataGenerator(rescale=1./255)

# %%
input_shape = (224, 224)

train = '/content/drive/MyDrive/Pratikum/dataset/train'
train_generator = datagen.flow_from_directory(train,
                                              target_size=input_shape,
                                              class_mode='categorical',
                                              batch_size=32,
                                              color_mode='rgb',
                                              shuffle= True)

validation = '/content/drive/MyDrive/Pratikum/dataset/val'
validation_generator = datagen.flow_from_directory(validation,
                                              target_size=input_shape,
                                              class_mode='categorical',
                                              batch_size=32,
                                              color_mode='rgb',
                                              shuffle= True)

test = '/content/drive/MyDrive/Pratikum/dataset/test'
test_generator = datagen.flow_from_directory(test,
                                              target_size=input_shape,
                                              batch_size=32,
                                              color_mode='rgb',
                                              shuffle= False)
# Out:
# Found 96 images belonging to 3 classes.
# Found 21 images belonging to 3 classes.
# Found 3 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout, Input, MaxPooling2D, concatenate
from tensorflow.keras.applications import Xception, ResNet50V2, EfficientNetB5, VGG16
from tensorflow.keras.optimizers import Adam
from keras.layers.merge import concatenate
from keras.layers import Input
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D,GlobalMaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input as densenet_preprocess
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

# %%
from tensorflow.keras.applications import Xception, ResNet50V2, EfficientNetB5, VGG16

# %%
resnet =ResNet50V2 (weights='imagenet', include_top=True)
resnet.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['post_relu[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,613,800
# Trainable params: 25,568,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.applications import Xception, ResNet50V2, EfficientNetB5, VGG16
vgg = VGG16(weights='imagenet', include_top=True)
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 4s 0us/step
# 553476096/553467096 [==============================] - 4s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make a reference to VGG's input layer
inp = vgg.input

# make a new softmax layer with num_classes neurons
new_classification_layer = Dense(3, activation='softmax')

# connect our new layer to the second to last layer in VGG, and make a reference to it
out = new_classification_layer(vgg.layers[-2].output)

# create a new network between inp and out
model_new = Model(inp, out)

# %%
# make a reference to VGG's input layer
inp = resnet.input

# make a new softmax layer with num_classes neurons
new_classification_layer = Dense(3, activation='softmax')

# connect our new layer to the second to last layer in VGG, and make a reference to it
out = new_classification_layer(resnet.layers[-2].output)

# create a new network between inp and out
model = Model(inp, out)

# %%
# make all layers untrainable by freezing weights (except for last layer)
for l, layer in enumerate(model_new.layers[:-1]):
    layer.trainable = False

# ensure the last layer is trainable/not frozen
for l, layer in enumerate(model_new.layers[-1:]):
    layer.trainable = True

model_new.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_new.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense (Dense)               (None, 3)                 12291
#
# =================================================================
# Total params: 134,272,835
# Trainable params: 12,291
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
# make all layers untrainable by freezing weights (except for last layer)
for l, layer in enumerate(model.layers[:-1]):
    layer.trainable = False

# ensure the last layer is trainable/not frozen
for l, layer in enumerate(model.layers[-1:]):
    layer.trainable = True

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['post_relu[0][0]']
#  2D)
#
#  dense (Dense)                  (None, 3)            6147        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 23,570,947
# Trainable params: 6,147
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
def callback(path):
  checkpoint_callback = ModelCheckpoint(path,
                                      monitor='val_accuracy',
                                      save_best_only=True,
                                      verbose=1)
  reduce_callback = ReduceLROnPlateau(monitor='val_accuracy', patience=3, factor=0.5, min_lr=0.000001, verbose=1)
  callbacks_list = [checkpoint_callback, reduce_callback]
  return callbacks_list

# %%
best_model_path = 'best_model2.h5'
cb=callback(best_model_path)

# %%
best_model_path3 = 'best_model3.h5'
cb3=callback(best_model_path3)

# %%
optm = Adam(lr=0.0001)
model_new.compile(loss='categorical_crossentropy', optimizer=optm, 
                  metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history1 = model_new.fit(train_generator, 
                         epochs=100, 
                         validation_data = validation_generator)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 41s 12s/step - loss: 0.7344 - accuracy: 0.3021 - val_loss: 0.5712 - val_accuracy: 0.6667
# Epoch 2/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.6596 - accuracy: 0.3958 - val_loss: 0.5762 - val_accuracy: 0.5714
# Epoch 3/100
# 3/3 [==============================] - 27s 10s/step - loss: 0.6141 - accuracy: 0.5208 - val_loss: 0.5635 - val_accuracy: 0.5238
# Epoch 4/100
# 3/3 [==============================] - 39s 14s/step - loss: 0.5543 - accuracy: 0.6042 - val_loss: 0.5461 - val_accuracy: 0.5238
# Epoch 5/100
# 3/3 [==============================] - 30s 10s/step - loss: 0.5060 - accuracy: 0.6771 - val_loss: 0.5376 - val_accuracy: 0.5714
# Epoch 6/100
# 3/3 [==============================] - 38s 14s/step - loss: 0.4687 - accuracy: 0.7500 - val_loss: 0.5317 - val_accuracy: 0.5714
# Epoch 7/100
# 3/3 [==============================] - 41s 14s/step - loss: 0.4357 - accuracy: 0.7917 - val_loss: 0.5232 - val_accuracy: 0.5714
# Epoch 8/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.4039 - accuracy: 0.7917 - val_loss: 0.5158 - val_accuracy: 0.6190
# Epoch 9/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.3756 - accuracy: 0.8333 - val_loss: 0.5111 - val_accuracy: 0.5714
# Epoch 10/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.3537 - accuracy: 0.8229 - val_loss: 0.5075 - val_accuracy: 0.5714
# Epoch 11/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.3339 - accuracy: 0.8229 - val_loss: 0.5014 - val_accuracy: 0.6190
# Epoch 12/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.3157 - accuracy: 0.8542 - val_loss: 0.4943 - val_accuracy: 0.5714
# Epoch 13/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.2984 - accuracy: 0.8542 - val_loss: 0.4869 - val_accuracy: 0.5714
# Epoch 14/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.2832 - accuracy: 0.8542 - val_loss: 0.4811 - val_accuracy: 0.6190
# Epoch 15/100
# 3/3 [==============================] - 24s 9s/step - loss: 0.2703 - accuracy: 0.8750 - val_loss: 0.4747 - val_accuracy: 0.6190
# Epoch 16/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.2586 - accuracy: 0.8854 - val_loss: 0.4685 - val_accuracy: 0.6190
# Epoch 17/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.2466 - accuracy: 0.8958 - val_loss: 0.4632 - val_accuracy: 0.6667
# Epoch 18/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.2360 - accuracy: 0.9167 - val_loss: 0.4573 - val_accuracy: 0.7143
# Epoch 19/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.2261 - accuracy: 0.9271 - val_loss: 0.4519 - val_accuracy: 0.7619
# Epoch 20/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.2173 - accuracy: 0.9479 - val_loss: 0.4465 - val_accuracy: 0.7619
# Epoch 21/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.2093 - accuracy: 0.9583 - val_loss: 0.4405 - val_accuracy: 0.7619
# Epoch 22/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.2009 - accuracy: 0.9688 - val_loss: 0.4345 - val_accuracy: 0.7619
# Epoch 23/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1938 - accuracy: 0.9792 - val_loss: 0.4286 - val_accuracy: 0.7619
# Epoch 24/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1866 - accuracy: 0.9792 - val_loss: 0.4238 - val_accuracy: 0.7619
# Epoch 25/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1798 - accuracy: 0.9896 - val_loss: 0.4196 - val_accuracy: 0.7619
# Epoch 26/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1739 - accuracy: 1.0000 - val_loss: 0.4155 - val_accuracy: 0.7619
# Epoch 27/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1680 - accuracy: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.8095
# Epoch 28/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1621 - accuracy: 1.0000 - val_loss: 0.4091 - val_accuracy: 0.8095
# Epoch 29/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1572 - accuracy: 1.0000 - val_loss: 0.4056 - val_accuracy: 0.8095
# Epoch 30/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1528 - accuracy: 1.0000 - val_loss: 0.4026 - val_accuracy: 0.8095
# Epoch 31/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.1475 - accuracy: 1.0000 - val_loss: 0.3992 - val_accuracy: 0.8095
# Epoch 32/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1429 - accuracy: 1.0000 - val_loss: 0.3955 - val_accuracy: 0.8095
# Epoch 33/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1386 - accuracy: 1.0000 - val_loss: 0.3924 - val_accuracy: 0.8095
# Epoch 34/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1348 - accuracy: 1.0000 - val_loss: 0.3901 - val_accuracy: 0.8095
# Epoch 35/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1307 - accuracy: 1.0000 - val_loss: 0.3875 - val_accuracy: 0.8095
# Epoch 36/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1269 - accuracy: 1.0000 - val_loss: 0.3851 - val_accuracy: 0.8095
# Epoch 37/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.1232 - accuracy: 1.0000 - val_loss: 0.3831 - val_accuracy: 0.8571
# Epoch 38/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1203 - accuracy: 1.0000 - val_loss: 0.3814 - val_accuracy: 0.8571
# Epoch 39/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.1168 - accuracy: 1.0000 - val_loss: 0.3793 - val_accuracy: 0.8571
# Epoch 40/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1140 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.8571
# Epoch 41/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.1106 - accuracy: 1.0000 - val_loss: 0.3756 - val_accuracy: 0.8571
# Epoch 42/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1079 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.8571
# Epoch 43/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.1050 - accuracy: 1.0000 - val_loss: 0.3730 - val_accuracy: 0.8571
# Epoch 44/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.1025 - accuracy: 1.0000 - val_loss: 0.3716 - val_accuracy: 0.8571
# Epoch 45/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.1000 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.8571
# Epoch 46/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0975 - accuracy: 1.0000 - val_loss: 0.3691 - val_accuracy: 0.8571
# Epoch 47/100
# 3/3 [==============================] - 24s 9s/step - loss: 0.0953 - accuracy: 1.0000 - val_loss: 0.3669 - val_accuracy: 0.8571
# Epoch 48/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0930 - accuracy: 1.0000 - val_loss: 0.3665 - val_accuracy: 0.8571
# Epoch 49/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0908 - accuracy: 1.0000 - val_loss: 0.3658 - val_accuracy: 0.8571
# Epoch 50/100
# 3/3 [==============================] - 25s 8s/step - loss: 0.0887 - accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.8571
# Epoch 51/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0866 - accuracy: 1.0000 - val_loss: 0.3628 - val_accuracy: 0.8571
# Epoch 52/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0848 - accuracy: 1.0000 - val_loss: 0.3618 - val_accuracy: 0.8571
# Epoch 53/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0829 - accuracy: 1.0000 - val_loss: 0.3606 - val_accuracy: 0.8571
# Epoch 54/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0809 - accuracy: 1.0000 - val_loss: 0.3594 - val_accuracy: 0.8571
# Epoch 55/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0792 - accuracy: 1.0000 - val_loss: 0.3589 - val_accuracy: 0.8571
# Epoch 56/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0775 - accuracy: 1.0000 - val_loss: 0.3580 - val_accuracy: 0.8571
# Epoch 57/100
# 3/3 [==============================] - 25s 9s/step - loss: 0.0759 - accuracy: 1.0000 - val_loss: 0.3571 - val_accuracy: 0.8571
# Epoch 58/100
# 3/3 [==============================] - 26s 9s/step - loss: 0.0742 - accuracy: 1.0000 - val_loss: 0.3571 - val_accuracy: 0.8571
# Epoch 59/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0729 - accuracy: 1.0000 - val_loss: 0.3565 - val_accuracy: 0.8571
# Epoch 60/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.3552 - val_accuracy: 0.8571
# Epoch 61/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0698 - accuracy: 1.0000 - val_loss: 0.3544 - val_accuracy: 0.8571
# Epoch 62/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0685 - accuracy: 1.0000 - val_loss: 0.3539 - val_accuracy: 0.8571
# Epoch 63/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 0.8571
# Epoch 64/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0659 - accuracy: 1.0000 - val_loss: 0.3527 - val_accuracy: 0.8571
# Epoch 65/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0646 - accuracy: 1.0000 - val_loss: 0.3525 - val_accuracy: 0.8571
# Epoch 66/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0634 - accuracy: 1.0000 - val_loss: 0.3525 - val_accuracy: 0.8571
# Epoch 67/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.3520 - val_accuracy: 0.8571
# Epoch 68/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.3510 - val_accuracy: 0.8571
# Epoch 69/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 0.3504 - val_accuracy: 0.8571
# Epoch 70/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.3498 - val_accuracy: 0.8571
# Epoch 71/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 0.3495 - val_accuracy: 0.8571
# Epoch 72/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 0.3503 - val_accuracy: 0.8095
# Epoch 73/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.3504 - val_accuracy: 0.8095
# Epoch 74/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.3490 - val_accuracy: 0.8095
# Epoch 75/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.3487 - val_accuracy: 0.8095
# Epoch 76/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.3479 - val_accuracy: 0.8095
# Epoch 77/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.3476 - val_accuracy: 0.8095
# Epoch 78/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.3470 - val_accuracy: 0.8571
# Epoch 79/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.3468 - val_accuracy: 0.8095
# Epoch 80/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.3467 - val_accuracy: 0.8095
# Epoch 81/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0486 - accuracy: 1.0000 - val_loss: 0.3468 - val_accuracy: 0.8095
# Epoch 82/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0478 - accuracy: 1.0000 - val_loss: 0.3471 - val_accuracy: 0.8095
# Epoch 83/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0471 - accuracy: 1.0000 - val_loss: 0.3472 - val_accuracy: 0.8095
# Epoch 84/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0463 - accuracy: 1.0000 - val_loss: 0.3469 - val_accuracy: 0.8095
# Epoch 85/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.3464 - val_accuracy: 0.8095
# Epoch 86/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.3460 - val_accuracy: 0.8095
# Epoch 87/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.3455 - val_accuracy: 0.8095
# Epoch 88/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.3455 - val_accuracy: 0.8095
# Epoch 89/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.3449 - val_accuracy: 0.8095
# Epoch 90/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 0.3450 - val_accuracy: 0.8095
# Epoch 91/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.3452 - val_accuracy: 0.8095
# Epoch 92/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.3450 - val_accuracy: 0.8095
# Epoch 93/100
# 3/3 [==============================] - 23s 8s/step - loss: 0.0404 - accuracy: 1.0000 - val_loss: 0.3449 - val_accuracy: 0.8095
# Epoch 94/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.3452 - val_accuracy: 0.8095
# Epoch 95/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.3455 - val_accuracy: 0.8095
# Epoch 96/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.3450 - val_accuracy: 0.8095
# Epoch 97/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.8095
# Epoch 98/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.8095
# Epoch 99/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.8095
# Epoch 100/100
# 3/3 [==============================] - 24s 8s/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.3449 - val_accuracy: 0.8095

# %%
from keras.applications.vgg19 import VGG19
vgg19_base = VGG19(
    include_top=False,
    input_shape=(224, 224, 3)
    )

for layer in vgg19_base.layers:
    layer.trainable = False

# %%
from keras.models import Sequential
model2 = Sequential()

model2.add(vgg19_base)

model2.add(Flatten())

model2.add(Dense(1024, activation='relu'))
model2.add(Dense(512, activation='relu'))
model2.add(Dense(64, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(0.3))

model2.add(Dense(3, activation='softmax'))

# %%
optm = Adam(lr=0.0001)
model2.compile(loss='categorical_crossentropy', optimizer=optm, 
                  metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model2,
        #    to_file='model_viz.png',
           show_shapes=True,
           show_layer_names=True
           )

# %%
history3 = model2.fit(train_generator,
                              epochs = 100,
                              validation_data = (validation_generator),
                              verbose=1, callbacks=[cb])
# Out:
# Epoch 1/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9830 - accuracy: 0.4896
# Epoch 00001: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 92s 32s/step - loss: 0.9830 - accuracy: 0.4896 - val_loss: 12.0005 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3498 - accuracy: 0.8750
# Epoch 00002: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 86s 31s/step - loss: 0.3498 - accuracy: 0.8750 - val_loss: 18.1379 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9583
# Epoch 00003: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.2068 - accuracy: 0.9583 - val_loss: 20.3966 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9479
# Epoch 00004: val_accuracy did not improve from 0.76190
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 3/3 [==============================] - 79s 28s/step - loss: 0.1956 - accuracy: 0.9479 - val_loss: 20.7675 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9896
# Epoch 00005: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.1171 - accuracy: 0.9896 - val_loss: 18.9416 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 6/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9896
# Epoch 00006: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0947 - accuracy: 0.9896 - val_loss: 17.7876 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 7/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9479
# Epoch 00007: val_accuracy did not improve from 0.76190
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 3/3 [==============================] - 78s 28s/step - loss: 0.1402 - accuracy: 0.9479 - val_loss: 17.2744 - val_accuracy: 0.3333 - lr: 5.0000e-04
# Epoch 8/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9896
# Epoch 00008: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0911 - accuracy: 0.9896 - val_loss: 16.1399 - val_accuracy: 0.3333 - lr: 2.5000e-04
# Epoch 9/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 1.0000
# Epoch 00009: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 15.0220 - val_accuracy: 0.3333 - lr: 2.5000e-04
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9896
# Epoch 00010: val_accuracy did not improve from 0.76190
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 3/3 [==============================] - 79s 28s/step - loss: 0.0941 - accuracy: 0.9896 - val_loss: 13.9531 - val_accuracy: 0.3333 - lr: 2.5000e-04
# Epoch 11/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 1.0000
# Epoch 00011: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 13.0010 - val_accuracy: 0.3333 - lr: 1.2500e-04
# Epoch 12/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9896
# Epoch 00012: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0777 - accuracy: 0.9896 - val_loss: 12.2314 - val_accuracy: 0.3333 - lr: 1.2500e-04
# Epoch 13/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 1.0000
# Epoch 00013: val_accuracy did not improve from 0.76190
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 3/3 [==============================] - 78s 28s/step - loss: 0.0720 - accuracy: 1.0000 - val_loss: 11.5954 - val_accuracy: 0.3333 - lr: 1.2500e-04
# Epoch 14/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 1.0000
# Epoch 00014: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 10.9630 - val_accuracy: 0.3333 - lr: 6.2500e-05
# Epoch 15/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9896
# Epoch 00015: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0669 - accuracy: 0.9896 - val_loss: 10.3792 - val_accuracy: 0.3333 - lr: 6.2500e-05
# Epoch 16/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9896
# Epoch 00016: val_accuracy did not improve from 0.76190
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 3/3 [==============================] - 78s 28s/step - loss: 0.0973 - accuracy: 0.9896 - val_loss: 9.7928 - val_accuracy: 0.3333 - lr: 6.2500e-05
# Epoch 17/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9896
# Epoch 00017: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0748 - accuracy: 0.9896 - val_loss: 9.2564 - val_accuracy: 0.3333 - lr: 3.1250e-05
# Epoch 18/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 1.0000
# Epoch 00018: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 84s 31s/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 8.7654 - val_accuracy: 0.3333 - lr: 3.1250e-05
# Epoch 19/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 1.0000
# Epoch 00019: val_accuracy did not improve from 0.76190
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 3/3 [==============================] - 78s 28s/step - loss: 0.0568 - accuracy: 1.0000 - val_loss: 8.2738 - val_accuracy: 0.3333 - lr: 3.1250e-05
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 1.0000
# Epoch 00020: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 7.8248 - val_accuracy: 0.3333 - lr: 1.5625e-05
# Epoch 21/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 1.0000
# Epoch 00021: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 7.4041 - val_accuracy: 0.3333 - lr: 1.5625e-05
# Epoch 22/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 1.0000
# Epoch 00022: val_accuracy did not improve from 0.76190
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 3/3 [==============================] - 78s 28s/step - loss: 0.0561 - accuracy: 1.0000 - val_loss: 7.0146 - val_accuracy: 0.3333 - lr: 1.5625e-05
# Epoch 23/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 1.0000
# Epoch 00023: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 85s 31s/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 6.6591 - val_accuracy: 0.3333 - lr: 7.8125e-06
# Epoch 24/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0702 - accuracy: 1.0000 - val_loss: 6.3089 - val_accuracy: 0.3333 - lr: 7.8125e-06
# Epoch 25/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 1.0000
# Epoch 00025: val_accuracy did not improve from 0.76190
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 3/3 [==============================] - 79s 28s/step - loss: 0.0604 - accuracy: 1.0000 - val_loss: 5.9850 - val_accuracy: 0.3333 - lr: 7.8125e-06
# Epoch 26/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 5.6751 - val_accuracy: 0.3333 - lr: 3.9063e-06
# Epoch 27/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 1.0000
# Epoch 00027: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0808 - accuracy: 1.0000 - val_loss: 5.3885 - val_accuracy: 0.3333 - lr: 3.9063e-06
# Epoch 28/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.76190
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 3/3 [==============================] - 78s 28s/step - loss: 0.0573 - accuracy: 1.0000 - val_loss: 5.1254 - val_accuracy: 0.3333 - lr: 3.9063e-06
# Epoch 29/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 85s 31s/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 4.8753 - val_accuracy: 0.3333 - lr: 1.9531e-06
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 4.6278 - val_accuracy: 0.3333 - lr: 1.9531e-06
# Epoch 31/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 1.0000
# Epoch 00031: val_accuracy did not improve from 0.76190
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3/3 [==============================] - 79s 28s/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 4.3949 - val_accuracy: 0.3333 - lr: 1.9531e-06
# Epoch 32/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0472 - accuracy: 1.0000 - val_loss: 4.1757 - val_accuracy: 0.3333 - lr: 1.0000e-06
# Epoch 33/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9896
# Epoch 00033: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0675 - accuracy: 0.9896 - val_loss: 3.9697 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 34/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9792
# Epoch 00034: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0889 - accuracy: 0.9792 - val_loss: 3.7765 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 35/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 3.5917 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 36/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 1.0000
# Epoch 00036: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 80s 28s/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 3.4222 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 37/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 81s 29s/step - loss: 0.0748 - accuracy: 1.0000 - val_loss: 3.2594 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 38/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0455 - accuracy: 1.0000 - val_loss: 3.1019 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 39/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0624 - accuracy: 1.0000 - val_loss: 2.9569 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 40/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 2.8198 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 41/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 2.6880 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 42/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0674 - accuracy: 1.0000 - val_loss: 2.5684 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 43/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 2.4526 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 44/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 2.3408 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 45/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 2.2374 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 46/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0425 - accuracy: 1.0000 - val_loss: 2.1381 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 47/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0499 - accuracy: 1.0000 - val_loss: 2.0438 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 48/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 1.9547 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 49/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0675 - accuracy: 1.0000 - val_loss: 1.8720 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 50/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0487 - accuracy: 1.0000 - val_loss: 1.7937 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 51/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 1.7206 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 52/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 1.6531 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 53/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0427 - accuracy: 1.0000 - val_loss: 1.5891 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 54/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 1.0000
# Epoch 00054: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 1.5282 - val_accuracy: 0.3810 - lr: 1.0000e-06
# Epoch 55/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 1.4723 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 56/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0680 - accuracy: 1.0000 - val_loss: 1.4200 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 57/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0589 - accuracy: 1.0000 - val_loss: 1.3697 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 58/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 1.3237 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 59/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 1.2804 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 60/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 1.2401 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 61/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9896
# Epoch 00061: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0581 - accuracy: 0.9896 - val_loss: 1.2021 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 62/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0727 - accuracy: 1.0000 - val_loss: 1.1672 - val_accuracy: 0.4286 - lr: 1.0000e-06
# Epoch 63/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 1.0000
# Epoch 00063: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0497 - accuracy: 1.0000 - val_loss: 1.1347 - val_accuracy: 0.4762 - lr: 1.0000e-06
# Epoch 64/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 29s/step - loss: 0.0692 - accuracy: 1.0000 - val_loss: 1.1050 - val_accuracy: 0.4762 - lr: 1.0000e-06
# Epoch 65/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 1.0000
# Epoch 00065: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 1.0775 - val_accuracy: 0.5238 - lr: 1.0000e-06
# Epoch 66/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9896
# Epoch 00066: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0817 - accuracy: 0.9896 - val_loss: 1.0516 - val_accuracy: 0.5238 - lr: 1.0000e-06
# Epoch 67/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0545 - accuracy: 1.0000 - val_loss: 1.0272 - val_accuracy: 0.5238 - lr: 1.0000e-06
# Epoch 68/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0807 - accuracy: 1.0000 - val_loss: 1.0044 - val_accuracy: 0.5238 - lr: 1.0000e-06
# Epoch 69/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 0.9830 - val_accuracy: 0.5238 - lr: 1.0000e-06
# Epoch 70/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 0.9631 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 71/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.9443 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 72/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.9271 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 73/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 0.9113 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 74/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 0.8966 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 75/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9792
# Epoch 00075: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0823 - accuracy: 0.9792 - val_loss: 0.8828 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 76/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0483 - accuracy: 1.0000 - val_loss: 0.8699 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 77/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.8580 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 78/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.8475 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 79/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9896
# Epoch 00079: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0577 - accuracy: 0.9896 - val_loss: 0.8379 - val_accuracy: 0.6667 - lr: 1.0000e-06
# Epoch 80/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 0.8291 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 81/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0601 - accuracy: 1.0000 - val_loss: 0.8212 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 82/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0697 - accuracy: 1.0000 - val_loss: 0.8139 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 83/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0572 - accuracy: 1.0000 - val_loss: 0.8067 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 84/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.7990 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 85/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9896
# Epoch 00085: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0634 - accuracy: 0.9896 - val_loss: 0.7909 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 86/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 80s 29s/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.7836 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 87/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9896
# Epoch 00087: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0734 - accuracy: 0.9896 - val_loss: 0.7766 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 88/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0553 - accuracy: 1.0000 - val_loss: 0.7702 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 89/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0455 - accuracy: 1.0000 - val_loss: 0.7648 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 90/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.7602 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 91/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.7562 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 92/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 78s 28s/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.7524 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 93/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0453 - accuracy: 1.0000 - val_loss: 0.7495 - val_accuracy: 0.5714 - lr: 1.0000e-06
# Epoch 94/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0618 - accuracy: 1.0000 - val_loss: 0.7465 - val_accuracy: 0.6190 - lr: 1.0000e-06
# Epoch 95/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0857 - accuracy: 1.0000 - val_loss: 0.7436 - val_accuracy: 0.6667 - lr: 1.0000e-06
# Epoch 96/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0626 - accuracy: 1.0000 - val_loss: 0.7413 - val_accuracy: 0.6667 - lr: 1.0000e-06
# Epoch 97/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0603 - accuracy: 1.0000 - val_loss: 0.7388 - val_accuracy: 0.6667 - lr: 1.0000e-06
# Epoch 98/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 0.7368 - val_accuracy: 0.6667 - lr: 1.0000e-06
# Epoch 99/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.7353 - val_accuracy: 0.6667 - lr: 1.0000e-06
# Epoch 100/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.76190
# 3/3 [==============================] - 79s 28s/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.7338 - val_accuracy: 0.6667 - lr: 1.0000e-06

# %%
converter_model = tf.lite.TFLiteConverter.from_keras_model(model2) 
tflite_model = converter_model.convert()

with open('model2.tflite', 'wb') as f: 
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpsb5zw5oh/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
converter_model = tf.lite.TFLiteConverter.from_keras_model(model_new) 
tflite_model = converter_model.convert()

with open('model.tflite', 'wb') as f: 
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp9xwlon5k/assets
# INFO:tensorflow:Assets written to: /tmp/tmp9xwlon5k/assets

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.style.use("ggplot")
fig =plt.figure()
plt.plot(np.arange(0, 100), history1.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), history1.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()
image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'Los.svg'

plt.style.use("ggplot")
fig2=plt.figure()
plt.plot(np.arange(0, 100), history1.history["acc"], label="train_accuracy")
plt.plot(np.arange(0, 100), history1.history["val_acc"], label="val_accuracy")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()
image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'Accuracy.svg'

fig2.savefig(image_name, format=image_format, dpi=1200)

fig.savefig(image_name, format=image_format, dpi=1200)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.style.use("ggplot")
fig3 =plt.figure()
plt.plot(np.arange(0, 100), history3.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), history3.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()
image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'Los.svg'

plt.style.use("ggplot")
fig4=plt.figure()
plt.plot(np.arange(0, 100), history3.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, 100), history3.history["val_accuracy"], label="val_accuracy")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()
image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'Accuracy.svg'

fig3.savefig(image_name, format=image_format, dpi=1200)

fig4.savefig(image_name, format=image_format, dpi=1200)
